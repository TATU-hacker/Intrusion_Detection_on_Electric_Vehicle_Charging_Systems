# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
from datetime import datetime
from river import stream, compose, preprocessing, forest, metrics, drift
from sklearn.utils import shuffle
from river import evaluate
from collections import Counter

# %%
df = pd.read_csv('CICEVSE2024_NT.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1277367 entries, 0 to 1277366
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count    Dtype
# ---  ------                        --------------    -----
#  0   protocol                      1277367 non-null  int64
#  1   ip_version                    1277367 non-null  int64
#  2   bidirectional_first_seen_ms   1277367 non-null  int64
#  3   bidirectional_last_seen_ms    1277367 non-null  int64
#  4   bidirectional_duration_ms     1277367 non-null  int64
#  5   bidirectional_packets         1277367 non-null  int64
#  6   bidirectional_bytes           1277367 non-null  int64
#  7   src2dst_first_seen_ms         1277367 non-null  int64
#  8   src2dst_last_seen_ms          1277367 non-null  int64
#  9   src2dst_duration_ms           1277367 non-null  int64
#  10  src2dst_packets               1277367 non-null  int64
#  11  src2dst_bytes                 1277367 non-null  int64
#  12  dst2src_first_seen_ms         1277367 non-null  int64
#  13  dst2src_last_seen_ms          1277367 non-null  int64
#  14  dst2src_packets               1277367 non-null  int64
#  15  dst2src_bytes                 1277367 non-null  int64
#  16  bidirectional_min_ps          1277367 non-null  int64
#  17  bidirectional_mean_ps         1277367 non-null  float64
#  18  bidirectional_max_ps          1277367 non-null  int64
#  19  src2dst_min_ps                1277367 non-null  int64
#  20  src2dst_mean_ps               1277367 non-null  float64
#  21  src2dst_max_ps                1277367 non-null  int64
#  22  dst2src_min_ps                1277367 non-null  int64
#  23  dst2src_mean_ps               1277367 non-null  float64
#  24  dst2src_max_ps                1277367 non-null  int64
#  25  bidirectional_min_piat_ms     1277367 non-null  int64
#  26  bidirectional_mean_piat_ms    1277367 non-null  float64
#  27  bidirectional_stddev_piat_ms  1277367 non-null  float64
#  28  bidirectional_max_piat_ms     1277367 non-null  int64
#  29  src2dst_min_piat_ms           1277367 non-null  int64
#  30  src2dst_mean_piat_ms          1277367 non-null  float64
#  31  src2dst_stddev_piat_ms        1277367 non-null  float64
#  32  src2dst_max_piat_ms           1277367 non-null  int64
#  33  bidirectional_syn_packets     1277367 non-null  int64
#  34  bidirectional_ack_packets     1277367 non-null  int64
#  35  bidirectional_rst_packets     1277367 non-null  int64
#  36  src2dst_syn_packets           1277367 non-null  int64
#  37  dst2src_ack_packets           1277367 non-null  int64
#  38  dst2src_rst_packets           1277367 non-null  int64
#  39  application_is_guessed        1277367 non-null  int64
#  40  application_confidence        1277367 non-null  int64
#  41  Label                         1277367 non-null  object
# dtypes: float64(7), int64(34), object(1)
# memory usage: 409.3+ MB

# %%
print(df['Label'].value_counts())
# Out:
# Label
# SYN_Flood                    259481
# SynonymousIP_Flood           256730
# TCP_Flood                    256315
# PSHACK_Flood                 195952
# SYN_Stealth_Scan              77278
# TCP_Port_Scan                 64455
# Service_Version_Detection     46334
# Vulnerability_Scan            38023
# UDP_Flood                     32475
# OS_Fingerprinting             26080
# Aggressive_Scan               21762
# Slowloris_Scan                 2340
# Benign                           82
# ICMP_Flood                       32
# ICMP_Fragmentation               28
# Name: count, dtype: int64

# %%
df['Label'] = df['Label'].map(lambda a: 0 if a == 'Benign' else 1)

# %% [markdown]
# # Online Learning Model

# %%
# Step 1: Preprocess and Balance Data
X = df.drop(columns=['Label'])  # Ensure 'Label' is the correct column name for your target
y = df['Label']

X, y = shuffle(X, y, random_state=42)

# Simulate data streaming
dataset = stream.iter_pandas(X, y)

# %%
# Step 2: Define Preprocessing and Classifier
model = compose.Pipeline(
    ('scaler', preprocessing.StandardScaler()),  # Normalize the data
    ('classifier', forest.ARFClassifier(
        seed=42,
        n_models=20,               # Increase number of trees
        max_features=0.5,          # Use 50% of features for splits
        grace_period=30,           # Faster adaptation
        leaf_prediction='nb'     # Naïve Bayes at leaves
    ))
)

# %%
# Step 3: Define Metrics
metric_accuracy = metrics.Accuracy()
metric_precision = metrics.Precision()
metric_recall = metrics.Recall()
metric_f1 = metrics.F1()

# %%
# Step 4: Add Drift Detector
drift_detector = drift.ADWIN()

# Timing and visualization variables
start_time = time.time()
total_time = 0
drift_time_total = 0
metrics_time_total = 0
instance_count = 0
drift_events = []
processing_times = []
drift_time_per_instance = []
metrics_time_per_instance = []
metric_logs = {
    'accuracy': [],
    'precision': [],
    'recall': [],
    'f1_score': []
}

# %%
# Step 5: Train, Evaluate, and Detect Drift
for x, y_true in dataset:
    instance_start = time.time()

    # Prediction and learning
    y_pred = model.predict_one(x)
    model.learn_one(x, y_true)

    # Time spent on metrics
    metrics_start = time.time()
    metric_accuracy.update(y_true, y_pred)
    metric_precision.update(y_true, y_pred)
    metric_recall.update(y_true, y_pred)
    metric_f1.update(y_true, y_pred)
    metrics_time_total += time.time() - metrics_start
    metrics_time_per_instance.append(time.time() - metrics_start) ###

    # Log metrics
    metric_logs['accuracy'].append(metric_accuracy.get())
    metric_logs['precision'].append(metric_precision.get())
    metric_logs['recall'].append(metric_recall.get())
    metric_logs['f1_score'].append(metric_f1.get())

    # Drift detection
    drift_start = time.time()
    drift_detector.update(y_pred == y_true)
    if drift_detector.drift_detected:
        detection_time = datetime.now()
        drift_events.append(instance_count)
        print(f"\nDrift detected at instance: {instance_count}")
        print(f"Detection Time: {detection_time}\n")
    drift_time_total += time.time() - drift_start
    drift_time_per_instance.append(time.time() - drift_start) ###

    # Update cumulative time
    instance_time = time.time() - instance_start
    total_time += instance_time
    processing_times.append(instance_time)
    instance_count += 1

    if instance_count % 100 == 0:
        print(f"Processed {instance_count}/{len(X)} instances")

# Summary of execution times
end_time = time.time()
# Out:
# Processed 100/1277367 instances
# Processed 200/1277367 instances
# Processed 300/1277367 instances
# Processed 400/1277367 instances
# Processed 500/1277367 instances
# Processed 600/1277367 instances
# Processed 700/1277367 instances
# Processed 800/1277367 instances
# Processed 900/1277367 instances
# Processed 1000/1277367 instances
# Processed 1100/1277367 instances
# Processed 1200/1277367 instances
# Processed 1300/1277367 instances
# Processed 1400/1277367 instances
# Processed 1500/1277367 instances
# Processed 1600/1277367 instances
# Processed 1700/1277367 instances
# Processed 1800/1277367 instances
# Processed 1900/1277367 instances
# Processed 2000/1277367 instances
# Processed 2100/1277367 instances
# Processed 2200/1277367 instances
# Processed 2300/1277367 instances
# Processed 2400/1277367 instances
# Processed 2500/1277367 instances
# Processed 2600/1277367 instances
# Processed 2700/1277367 instances
# Processed 2800/1277367 instances
# Processed 2900/1277367 instances
# Processed 3000/1277367 instances
# Processed 3100/1277367 instances
# Processed 3200/1277367 instances
# Processed 3300/1277367 instances
# Processed 3400/1277367 instances
# Processed 3500/1277367 instances
# Processed 3600/1277367 instances
# Processed 3700/1277367 instances
# Processed 3800/1277367 instances
# Processed 3900/1277367 instances
# Processed 4000/1277367 instances
# Processed 4100/1277367 instances
# Processed 4200/1277367 instances
# Processed 4300/1277367 instances
# Processed 4400/1277367 instances
# Processed 4500/1277367 instances
# Processed 4600/1277367 instances
# Processed 4700/1277367 instances
# Processed 4800/1277367 instances
# Processed 4900/1277367 instances
# Processed 5000/1277367 instances
# Processed 5100/1277367 instances
# Processed 5200/1277367 instances
# Processed 5300/1277367 instances
# Processed 5400/1277367 instances
# Processed 5500/1277367 instances
# Processed 5600/1277367 instances
# Processed 5700/1277367 instances
# Processed 5800/1277367 instances
# Processed 5900/1277367 instances
# Processed 6000/1277367 instances
# Processed 6100/1277367 instances
# Processed 6200/1277367 instances
# Processed 6300/1277367 instances
# Processed 6400/1277367 instances
# Processed 6500/1277367 instances
# Processed 6600/1277367 instances
# Processed 6700/1277367 instances
# Processed 6800/1277367 instances
# Processed 6900/1277367 instances
# Processed 7000/1277367 instances
# Processed 7100/1277367 instances
# Processed 7200/1277367 instances
# Processed 7300/1277367 instances
# Processed 7400/1277367 instances
# Processed 7500/1277367 instances
# Processed 7600/1277367 instances
# Processed 7700/1277367 instances
# Processed 7800/1277367 instances
# Processed 7900/1277367 instances
# Processed 8000/1277367 instances
# Processed 8100/1277367 instances
# Processed 8200/1277367 instances
# Processed 8300/1277367 instances
# Processed 8400/1277367 instances
# Processed 8500/1277367 instances
# Processed 8600/1277367 instances
# Processed 8700/1277367 instances
# Processed 8800/1277367 instances
# Processed 8900/1277367 instances
# Processed 9000/1277367 instances
# Processed 9100/1277367 instances
# Processed 9200/1277367 instances
# Processed 9300/1277367 instances
# Processed 9400/1277367 instances
# Processed 9500/1277367 instances
# Processed 9600/1277367 instances
# Processed 9700/1277367 instances
# Processed 9800/1277367 instances
# Processed 9900/1277367 instances
# Processed 10000/1277367 instances
# Processed 10100/1277367 instances
# Processed 10200/1277367 instances
# Processed 10300/1277367 instances
# Processed 10400/1277367 instances
# Processed 10500/1277367 instances
# Processed 10600/1277367 instances
# Processed 10700/1277367 instances
# Processed 10800/1277367 instances
# Processed 10900/1277367 instances
# Processed 11000/1277367 instances
# Processed 11100/1277367 instances
# Processed 11200/1277367 instances
# Processed 11300/1277367 instances
# Processed 11400/1277367 instances
# Processed 11500/1277367 instances
# Processed 11600/1277367 instances
# Processed 11700/1277367 instances
# Processed 11800/1277367 instances
# Processed 11900/1277367 instances
# Processed 12000/1277367 instances
# Processed 12100/1277367 instances
# Processed 12200/1277367 instances
# Processed 12300/1277367 instances
# Processed 12400/1277367 instances
# Processed 12500/1277367 instances
# Processed 12600/1277367 instances
# Processed 12700/1277367 instances
# Processed 12800/1277367 instances
# Processed 12900/1277367 instances
# Processed 13000/1277367 instances
# Processed 13100/1277367 instances
# Processed 13200/1277367 instances
# Processed 13300/1277367 instances
# Processed 13400/1277367 instances
# Processed 13500/1277367 instances
# Processed 13600/1277367 instances
# Processed 13700/1277367 instances
# Processed 13800/1277367 instances
# Processed 13900/1277367 instances
# Processed 14000/1277367 instances
# Processed 14100/1277367 instances
# Processed 14200/1277367 instances
# Processed 14300/1277367 instances
# Processed 14400/1277367 instances
# Processed 14500/1277367 instances
# Processed 14600/1277367 instances
# Processed 14700/1277367 instances
# Processed 14800/1277367 instances
# Processed 14900/1277367 instances
# Processed 15000/1277367 instances
# Processed 15100/1277367 instances
# Processed 15200/1277367 instances
# Processed 15300/1277367 instances
# Processed 15400/1277367 instances
# Processed 15500/1277367 instances
# Processed 15600/1277367 instances
# Processed 15700/1277367 instances
# Processed 15800/1277367 instances
# Processed 15900/1277367 instances
# Processed 16000/1277367 instances
# Processed 16100/1277367 instances
# Processed 16200/1277367 instances
# Processed 16300/1277367 instances
# Processed 16400/1277367 instances
# Processed 16500/1277367 instances
# Processed 16600/1277367 instances
# Processed 16700/1277367 instances
# Processed 16800/1277367 instances
# Processed 16900/1277367 instances
# Processed 17000/1277367 instances
# Processed 17100/1277367 instances
# Processed 17200/1277367 instances
# Processed 17300/1277367 instances
# Processed 17400/1277367 instances
# Processed 17500/1277367 instances
# Processed 17600/1277367 instances
# Processed 17700/1277367 instances
# Processed 17800/1277367 instances
# Processed 17900/1277367 instances
# Processed 18000/1277367 instances
#
# Drift detected at instance: 18047
# Detection Time: 2025-01-11 15:05:32.005376
#
# Processed 18100/1277367 instances
# Processed 18200/1277367 instances
# Processed 18300/1277367 instances
# Processed 18400/1277367 instances
# Processed 18500/1277367 instances
# Processed 18600/1277367 instances
# Processed 18700/1277367 instances
# Processed 18800/1277367 instances
# Processed 18900/1277367 instances
# Processed 19000/1277367 instances
# Processed 19100/1277367 instances
# Processed 19200/1277367 instances
# Processed 19300/1277367 instances
# Processed 19400/1277367 instances
# Processed 19500/1277367 instances
# Processed 19600/1277367 instances
# Processed 19700/1277367 instances
# Processed 19800/1277367 instances
# Processed 19900/1277367 instances
# Processed 20000/1277367 instances
# Processed 20100/1277367 instances
# Processed 20200/1277367 instances
# Processed 20300/1277367 instances
# Processed 20400/1277367 instances
# Processed 20500/1277367 instances
# Processed 20600/1277367 instances
# Processed 20700/1277367 instances
# Processed 20800/1277367 instances
# Processed 20900/1277367 instances
# Processed 21000/1277367 instances
# Processed 21100/1277367 instances
# Processed 21200/1277367 instances
# Processed 21300/1277367 instances
# Processed 21400/1277367 instances
# Processed 21500/1277367 instances
# Processed 21600/1277367 instances
# Processed 21700/1277367 instances
# Processed 21800/1277367 instances
# Processed 21900/1277367 instances
# Processed 22000/1277367 instances
# Processed 22100/1277367 instances
# Processed 22200/1277367 instances
# Processed 22300/1277367 instances
# Processed 22400/1277367 instances
# Processed 22500/1277367 instances
# Processed 22600/1277367 instances
# Processed 22700/1277367 instances
# Processed 22800/1277367 instances
# Processed 22900/1277367 instances
# Processed 23000/1277367 instances
# Processed 23100/1277367 instances
# Processed 23200/1277367 instances
# Processed 23300/1277367 instances
# Processed 23400/1277367 instances
# Processed 23500/1277367 instances
# Processed 23600/1277367 instances
# Processed 23700/1277367 instances
# Processed 23800/1277367 instances
# Processed 23900/1277367 instances
# Processed 24000/1277367 instances
# Processed 24100/1277367 instances
# Processed 24200/1277367 instances
# Processed 24300/1277367 instances
# Processed 24400/1277367 instances
# Processed 24500/1277367 instances
# Processed 24600/1277367 instances
# Processed 24700/1277367 instances
# Processed 24800/1277367 instances
# Processed 24900/1277367 instances
# Processed 25000/1277367 instances
# Processed 25100/1277367 instances
# Processed 25200/1277367 instances
# Processed 25300/1277367 instances
# Processed 25400/1277367 instances
# Processed 25500/1277367 instances
# Processed 25600/1277367 instances
# Processed 25700/1277367 instances
# Processed 25800/1277367 instances
# Processed 25900/1277367 instances
# Processed 26000/1277367 instances
# Processed 26100/1277367 instances
# Processed 26200/1277367 instances
# Processed 26300/1277367 instances
# Processed 26400/1277367 instances
# Processed 26500/1277367 instances
# Processed 26600/1277367 instances
# Processed 26700/1277367 instances
# Processed 26800/1277367 instances
# Processed 26900/1277367 instances
# Processed 27000/1277367 instances
# Processed 27100/1277367 instances
# Processed 27200/1277367 instances
# Processed 27300/1277367 instances
# Processed 27400/1277367 instances
# Processed 27500/1277367 instances
# Processed 27600/1277367 instances
# Processed 27700/1277367 instances
# Processed 27800/1277367 instances
# Processed 27900/1277367 instances
# Processed 28000/1277367 instances
# Processed 28100/1277367 instances
# Processed 28200/1277367 instances
# Processed 28300/1277367 instances
# Processed 28400/1277367 instances
# Processed 28500/1277367 instances
# Processed 28600/1277367 instances
# Processed 28700/1277367 instances
# Processed 28800/1277367 instances
# Processed 28900/1277367 instances
# Processed 29000/1277367 instances
# Processed 29100/1277367 instances
# Processed 29200/1277367 instances
# Processed 29300/1277367 instances
# Processed 29400/1277367 instances
# Processed 29500/1277367 instances
# Processed 29600/1277367 instances
# Processed 29700/1277367 instances
# Processed 29800/1277367 instances
# Processed 29900/1277367 instances
# Processed 30000/1277367 instances
# Processed 30100/1277367 instances
# Processed 30200/1277367 instances
# Processed 30300/1277367 instances
# Processed 30400/1277367 instances
# Processed 30500/1277367 instances
# Processed 30600/1277367 instances
# Processed 30700/1277367 instances
# Processed 30800/1277367 instances
# Processed 30900/1277367 instances
# Processed 31000/1277367 instances
# Processed 31100/1277367 instances
# Processed 31200/1277367 instances
# Processed 31300/1277367 instances
# Processed 31400/1277367 instances
# Processed 31500/1277367 instances
# Processed 31600/1277367 instances
# Processed 31700/1277367 instances
# Processed 31800/1277367 instances
# Processed 31900/1277367 instances
# Processed 32000/1277367 instances
# Processed 32100/1277367 instances
# Processed 32200/1277367 instances
# Processed 32300/1277367 instances
# Processed 32400/1277367 instances
# Processed 32500/1277367 instances
# Processed 32600/1277367 instances
# Processed 32700/1277367 instances
# Processed 32800/1277367 instances
# Processed 32900/1277367 instances
# Processed 33000/1277367 instances
# Processed 33100/1277367 instances
# Processed 33200/1277367 instances
# Processed 33300/1277367 instances
# Processed 33400/1277367 instances
# Processed 33500/1277367 instances
# Processed 33600/1277367 instances
# Processed 33700/1277367 instances
# Processed 33800/1277367 instances
# Processed 33900/1277367 instances
# Processed 34000/1277367 instances
# Processed 34100/1277367 instances
# Processed 34200/1277367 instances
# Processed 34300/1277367 instances
# Processed 34400/1277367 instances
# Processed 34500/1277367 instances
# Processed 34600/1277367 instances
# Processed 34700/1277367 instances
# Processed 34800/1277367 instances
# Processed 34900/1277367 instances
# Processed 35000/1277367 instances
# Processed 35100/1277367 instances
# Processed 35200/1277367 instances
# Processed 35300/1277367 instances
# Processed 35400/1277367 instances
# Processed 35500/1277367 instances
# Processed 35600/1277367 instances
# Processed 35700/1277367 instances
# Processed 35800/1277367 instances
# Processed 35900/1277367 instances
# Processed 36000/1277367 instances
# Processed 36100/1277367 instances
# Processed 36200/1277367 instances
# Processed 36300/1277367 instances
# Processed 36400/1277367 instances
# Processed 36500/1277367 instances
# Processed 36600/1277367 instances
# Processed 36700/1277367 instances
# Processed 36800/1277367 instances
# Processed 36900/1277367 instances
# Processed 37000/1277367 instances
# Processed 37100/1277367 instances
# Processed 37200/1277367 instances
# Processed 37300/1277367 instances
# Processed 37400/1277367 instances
# Processed 37500/1277367 instances
# Processed 37600/1277367 instances
# Processed 37700/1277367 instances
# Processed 37800/1277367 instances
# Processed 37900/1277367 instances
# Processed 38000/1277367 instances
# Processed 38100/1277367 instances
# Processed 38200/1277367 instances
# Processed 38300/1277367 instances
# Processed 38400/1277367 instances
# Processed 38500/1277367 instances
# Processed 38600/1277367 instances
# Processed 38700/1277367 instances
# Processed 38800/1277367 instances
# Processed 38900/1277367 instances
# Processed 39000/1277367 instances
# Processed 39100/1277367 instances
# Processed 39200/1277367 instances
# Processed 39300/1277367 instances
# Processed 39400/1277367 instances
# Processed 39500/1277367 instances
# Processed 39600/1277367 instances
# Processed 39700/1277367 instances
# Processed 39800/1277367 instances
# Processed 39900/1277367 instances
# Processed 40000/1277367 instances
# Processed 40100/1277367 instances
# Processed 40200/1277367 instances
# Processed 40300/1277367 instances
# Processed 40400/1277367 instances
# Processed 40500/1277367 instances
# Processed 40600/1277367 instances
# Processed 40700/1277367 instances
# Processed 40800/1277367 instances
# Processed 40900/1277367 instances
# Processed 41000/1277367 instances
# Processed 41100/1277367 instances
# Processed 41200/1277367 instances
# Processed 41300/1277367 instances
# Processed 41400/1277367 instances
# Processed 41500/1277367 instances
# Processed 41600/1277367 instances
# Processed 41700/1277367 instances
# Processed 41800/1277367 instances
# Processed 41900/1277367 instances
# Processed 42000/1277367 instances
# Processed 42100/1277367 instances
# Processed 42200/1277367 instances
# Processed 42300/1277367 instances
# Processed 42400/1277367 instances
# Processed 42500/1277367 instances
# Processed 42600/1277367 instances
# Processed 42700/1277367 instances
# Processed 42800/1277367 instances
# Processed 42900/1277367 instances
# Processed 43000/1277367 instances
# Processed 43100/1277367 instances
# Processed 43200/1277367 instances
# Processed 43300/1277367 instances
# Processed 43400/1277367 instances
# Processed 43500/1277367 instances
# Processed 43600/1277367 instances
# Processed 43700/1277367 instances
# Processed 43800/1277367 instances
# Processed 43900/1277367 instances
# Processed 44000/1277367 instances
# Processed 44100/1277367 instances
# Processed 44200/1277367 instances
# Processed 44300/1277367 instances
# Processed 44400/1277367 instances
# Processed 44500/1277367 instances
# Processed 44600/1277367 instances
# Processed 44700/1277367 instances
# Processed 44800/1277367 instances
# Processed 44900/1277367 instances
# Processed 45000/1277367 instances
# Processed 45100/1277367 instances
# Processed 45200/1277367 instances
# Processed 45300/1277367 instances
# Processed 45400/1277367 instances
# Processed 45500/1277367 instances
# Processed 45600/1277367 instances
# Processed 45700/1277367 instances
# Processed 45800/1277367 instances
# Processed 45900/1277367 instances
# Processed 46000/1277367 instances
# Processed 46100/1277367 instances
# Processed 46200/1277367 instances
# Processed 46300/1277367 instances
# Processed 46400/1277367 instances
# Processed 46500/1277367 instances
# Processed 46600/1277367 instances
# Processed 46700/1277367 instances
# Processed 46800/1277367 instances
# Processed 46900/1277367 instances
# Processed 47000/1277367 instances
# Processed 47100/1277367 instances
# Processed 47200/1277367 instances
# Processed 47300/1277367 instances
# Processed 47400/1277367 instances
# Processed 47500/1277367 instances
# Processed 47600/1277367 instances
# Processed 47700/1277367 instances
# Processed 47800/1277367 instances
# Processed 47900/1277367 instances
# Processed 48000/1277367 instances
# Processed 48100/1277367 instances
# Processed 48200/1277367 instances
# Processed 48300/1277367 instances
# Processed 48400/1277367 instances
# Processed 48500/1277367 instances
# Processed 48600/1277367 instances
# Processed 48700/1277367 instances
# Processed 48800/1277367 instances
# Processed 48900/1277367 instances
# Processed 49000/1277367 instances
# Processed 49100/1277367 instances
# Processed 49200/1277367 instances
# Processed 49300/1277367 instances
# Processed 49400/1277367 instances
# Processed 49500/1277367 instances
# Processed 49600/1277367 instances
# Processed 49700/1277367 instances
# Processed 49800/1277367 instances
# Processed 49900/1277367 instances
# Processed 50000/1277367 instances
# Processed 50100/1277367 instances
# Processed 50200/1277367 instances
# Processed 50300/1277367 instances
# Processed 50400/1277367 instances
# Processed 50500/1277367 instances
# Processed 50600/1277367 instances
# Processed 50700/1277367 instances
# Processed 50800/1277367 instances
# Processed 50900/1277367 instances
# Processed 51000/1277367 instances
# Processed 51100/1277367 instances
# Processed 51200/1277367 instances
# Processed 51300/1277367 instances
# Processed 51400/1277367 instances
# Processed 51500/1277367 instances
# Processed 51600/1277367 instances
# Processed 51700/1277367 instances
# Processed 51800/1277367 instances
# Processed 51900/1277367 instances
# Processed 52000/1277367 instances
# Processed 52100/1277367 instances
# Processed 52200/1277367 instances
# Processed 52300/1277367 instances
# Processed 52400/1277367 instances
# Processed 52500/1277367 instances
# Processed 52600/1277367 instances
# Processed 52700/1277367 instances
# Processed 52800/1277367 instances
# Processed 52900/1277367 instances
# Processed 53000/1277367 instances
# Processed 53100/1277367 instances
# Processed 53200/1277367 instances
# Processed 53300/1277367 instances
# Processed 53400/1277367 instances
# Processed 53500/1277367 instances
# Processed 53600/1277367 instances
# Processed 53700/1277367 instances
# Processed 53800/1277367 instances
# Processed 53900/1277367 instances
# Processed 54000/1277367 instances
# Processed 54100/1277367 instances
# Processed 54200/1277367 instances
# Processed 54300/1277367 instances
# Processed 54400/1277367 instances
# Processed 54500/1277367 instances
# Processed 54600/1277367 instances
# Processed 54700/1277367 instances
# Processed 54800/1277367 instances
# Processed 54900/1277367 instances
# Processed 55000/1277367 instances
# Processed 55100/1277367 instances
# Processed 55200/1277367 instances
# Processed 55300/1277367 instances
# Processed 55400/1277367 instances
# Processed 55500/1277367 instances
# Processed 55600/1277367 instances
# Processed 55700/1277367 instances
# Processed 55800/1277367 instances
# Processed 55900/1277367 instances
# Processed 56000/1277367 instances
# Processed 56100/1277367 instances
# Processed 56200/1277367 instances
# Processed 56300/1277367 instances
# Processed 56400/1277367 instances
# Processed 56500/1277367 instances
# Processed 56600/1277367 instances
# Processed 56700/1277367 instances
# Processed 56800/1277367 instances
# Processed 56900/1277367 instances
# Processed 57000/1277367 instances
# Processed 57100/1277367 instances
# Processed 57200/1277367 instances
# Processed 57300/1277367 instances
# Processed 57400/1277367 instances
# Processed 57500/1277367 instances
# Processed 57600/1277367 instances
# Processed 57700/1277367 instances
# Processed 57800/1277367 instances
# Processed 57900/1277367 instances
# Processed 58000/1277367 instances
# Processed 58100/1277367 instances
# Processed 58200/1277367 instances
# Processed 58300/1277367 instances
# Processed 58400/1277367 instances
# Processed 58500/1277367 instances
# Processed 58600/1277367 instances
# Processed 58700/1277367 instances
# Processed 58800/1277367 instances
# Processed 58900/1277367 instances
# Processed 59000/1277367 instances
# Processed 59100/1277367 instances
# Processed 59200/1277367 instances
# Processed 59300/1277367 instances
# Processed 59400/1277367 instances
# Processed 59500/1277367 instances
# Processed 59600/1277367 instances
# Processed 59700/1277367 instances
# Processed 59800/1277367 instances
# Processed 59900/1277367 instances
# Processed 60000/1277367 instances
# Processed 60100/1277367 instances
# Processed 60200/1277367 instances
# Processed 60300/1277367 instances
# Processed 60400/1277367 instances
# Processed 60500/1277367 instances
#
# Drift detected at instance: 60511
# Detection Time: 2025-01-11 15:06:42.714280
#
# Processed 60600/1277367 instances
# Processed 60700/1277367 instances
# Processed 60800/1277367 instances
# Processed 60900/1277367 instances
# Processed 61000/1277367 instances
# Processed 61100/1277367 instances
# Processed 61200/1277367 instances
# Processed 61300/1277367 instances
# Processed 61400/1277367 instances
# Processed 61500/1277367 instances
# Processed 61600/1277367 instances
# Processed 61700/1277367 instances
# Processed 61800/1277367 instances
# Processed 61900/1277367 instances
# Processed 62000/1277367 instances
# Processed 62100/1277367 instances
# Processed 62200/1277367 instances
# Processed 62300/1277367 instances
# Processed 62400/1277367 instances
# Processed 62500/1277367 instances
# Processed 62600/1277367 instances
# Processed 62700/1277367 instances
# Processed 62800/1277367 instances
# Processed 62900/1277367 instances
# Processed 63000/1277367 instances
# Processed 63100/1277367 instances
# Processed 63200/1277367 instances
# Processed 63300/1277367 instances
# Processed 63400/1277367 instances
# Processed 63500/1277367 instances
# Processed 63600/1277367 instances
# Processed 63700/1277367 instances
# Processed 63800/1277367 instances
# Processed 63900/1277367 instances
# Processed 64000/1277367 instances
# Processed 64100/1277367 instances
# Processed 64200/1277367 instances
# Processed 64300/1277367 instances
# Processed 64400/1277367 instances
# Processed 64500/1277367 instances
# Processed 64600/1277367 instances
# Processed 64700/1277367 instances
# Processed 64800/1277367 instances
# Processed 64900/1277367 instances
# Processed 65000/1277367 instances
# Processed 65100/1277367 instances
# Processed 65200/1277367 instances
# Processed 65300/1277367 instances
# Processed 65400/1277367 instances
# Processed 65500/1277367 instances
# Processed 65600/1277367 instances
# Processed 65700/1277367 instances
# Processed 65800/1277367 instances
# Processed 65900/1277367 instances
# Processed 66000/1277367 instances
# Processed 66100/1277367 instances
# Processed 66200/1277367 instances
# Processed 66300/1277367 instances
# Processed 66400/1277367 instances
# Processed 66500/1277367 instances
# Processed 66600/1277367 instances
# Processed 66700/1277367 instances
# Processed 66800/1277367 instances
# Processed 66900/1277367 instances
# Processed 67000/1277367 instances
# Processed 67100/1277367 instances
# Processed 67200/1277367 instances
# Processed 67300/1277367 instances
# Processed 67400/1277367 instances
# Processed 67500/1277367 instances
# Processed 67600/1277367 instances
# Processed 67700/1277367 instances
# Processed 67800/1277367 instances
# Processed 67900/1277367 instances
# Processed 68000/1277367 instances
# Processed 68100/1277367 instances
# Processed 68200/1277367 instances
# Processed 68300/1277367 instances
# Processed 68400/1277367 instances
# Processed 68500/1277367 instances
# Processed 68600/1277367 instances
# Processed 68700/1277367 instances
# Processed 68800/1277367 instances
# Processed 68900/1277367 instances
# Processed 69000/1277367 instances
# Processed 69100/1277367 instances
# Processed 69200/1277367 instances
# Processed 69300/1277367 instances
# Processed 69400/1277367 instances
# Processed 69500/1277367 instances
# Processed 69600/1277367 instances
# Processed 69700/1277367 instances
# Processed 69800/1277367 instances
# Processed 69900/1277367 instances
# Processed 70000/1277367 instances
# Processed 70100/1277367 instances
# Processed 70200/1277367 instances
# Processed 70300/1277367 instances
# Processed 70400/1277367 instances
# Processed 70500/1277367 instances
# Processed 70600/1277367 instances
# Processed 70700/1277367 instances
# Processed 70800/1277367 instances
# Processed 70900/1277367 instances
# Processed 71000/1277367 instances
# Processed 71100/1277367 instances
# Processed 71200/1277367 instances
# Processed 71300/1277367 instances
# Processed 71400/1277367 instances
# Processed 71500/1277367 instances
# Processed 71600/1277367 instances
# Processed 71700/1277367 instances
# Processed 71800/1277367 instances
# Processed 71900/1277367 instances
# Processed 72000/1277367 instances
# Processed 72100/1277367 instances
# Processed 72200/1277367 instances
# Processed 72300/1277367 instances
# Processed 72400/1277367 instances
# Processed 72500/1277367 instances
# Processed 72600/1277367 instances
# Processed 72700/1277367 instances
# Processed 72800/1277367 instances
# Processed 72900/1277367 instances
# Processed 73000/1277367 instances
# Processed 73100/1277367 instances
# Processed 73200/1277367 instances
# Processed 73300/1277367 instances
# Processed 73400/1277367 instances
# Processed 73500/1277367 instances
# Processed 73600/1277367 instances
# Processed 73700/1277367 instances
# Processed 73800/1277367 instances
# Processed 73900/1277367 instances
# Processed 74000/1277367 instances
# Processed 74100/1277367 instances
# Processed 74200/1277367 instances
# Processed 74300/1277367 instances
# Processed 74400/1277367 instances
# Processed 74500/1277367 instances
# Processed 74600/1277367 instances
# Processed 74700/1277367 instances
# Processed 74800/1277367 instances
# Processed 74900/1277367 instances
# Processed 75000/1277367 instances
# Processed 75100/1277367 instances
# Processed 75200/1277367 instances
# Processed 75300/1277367 instances
# Processed 75400/1277367 instances
# Processed 75500/1277367 instances
# Processed 75600/1277367 instances
# Processed 75700/1277367 instances
# Processed 75800/1277367 instances
# Processed 75900/1277367 instances
# Processed 76000/1277367 instances
# Processed 76100/1277367 instances
# Processed 76200/1277367 instances
# Processed 76300/1277367 instances
# Processed 76400/1277367 instances
# Processed 76500/1277367 instances
# Processed 76600/1277367 instances
# Processed 76700/1277367 instances
# Processed 76800/1277367 instances
# Processed 76900/1277367 instances
# Processed 77000/1277367 instances
# Processed 77100/1277367 instances
# Processed 77200/1277367 instances
# Processed 77300/1277367 instances
# Processed 77400/1277367 instances
# Processed 77500/1277367 instances
# Processed 77600/1277367 instances
# Processed 77700/1277367 instances
# Processed 77800/1277367 instances
# Processed 77900/1277367 instances
# Processed 78000/1277367 instances
# Processed 78100/1277367 instances
# Processed 78200/1277367 instances
# Processed 78300/1277367 instances
# Processed 78400/1277367 instances
# Processed 78500/1277367 instances
# Processed 78600/1277367 instances
# Processed 78700/1277367 instances
# Processed 78800/1277367 instances
# Processed 78900/1277367 instances
# Processed 79000/1277367 instances
# Processed 79100/1277367 instances
# Processed 79200/1277367 instances
# Processed 79300/1277367 instances
# Processed 79400/1277367 instances
# Processed 79500/1277367 instances
# Processed 79600/1277367 instances
# Processed 79700/1277367 instances
# Processed 79800/1277367 instances
# Processed 79900/1277367 instances
# Processed 80000/1277367 instances
# Processed 80100/1277367 instances
# Processed 80200/1277367 instances
# Processed 80300/1277367 instances
# Processed 80400/1277367 instances
# Processed 80500/1277367 instances
# Processed 80600/1277367 instances
# Processed 80700/1277367 instances
# Processed 80800/1277367 instances
# Processed 80900/1277367 instances
# Processed 81000/1277367 instances
# Processed 81100/1277367 instances
# Processed 81200/1277367 instances
# Processed 81300/1277367 instances
# Processed 81400/1277367 instances
# Processed 81500/1277367 instances
# Processed 81600/1277367 instances
# Processed 81700/1277367 instances
# Processed 81800/1277367 instances
# Processed 81900/1277367 instances
# Processed 82000/1277367 instances
# Processed 82100/1277367 instances
# Processed 82200/1277367 instances
# Processed 82300/1277367 instances
# Processed 82400/1277367 instances
# Processed 82500/1277367 instances
# Processed 82600/1277367 instances
# Processed 82700/1277367 instances
# Processed 82800/1277367 instances
# Processed 82900/1277367 instances
# Processed 83000/1277367 instances
# Processed 83100/1277367 instances
# Processed 83200/1277367 instances
# Processed 83300/1277367 instances
# Processed 83400/1277367 instances
# Processed 83500/1277367 instances
# Processed 83600/1277367 instances
# Processed 83700/1277367 instances
# Processed 83800/1277367 instances
# Processed 83900/1277367 instances
# Processed 84000/1277367 instances
#
# Drift detected at instance: 84063
# Detection Time: 2025-01-11 15:07:22.446074
#
# Processed 84100/1277367 instances
# Processed 84200/1277367 instances
# Processed 84300/1277367 instances
# Processed 84400/1277367 instances
# Processed 84500/1277367 instances
# Processed 84600/1277367 instances
# Processed 84700/1277367 instances
# Processed 84800/1277367 instances
# Processed 84900/1277367 instances
# Processed 85000/1277367 instances
# Processed 85100/1277367 instances
# Processed 85200/1277367 instances
# Processed 85300/1277367 instances
# Processed 85400/1277367 instances
# Processed 85500/1277367 instances
# Processed 85600/1277367 instances
# Processed 85700/1277367 instances
# Processed 85800/1277367 instances
# Processed 85900/1277367 instances
# Processed 86000/1277367 instances
# Processed 86100/1277367 instances
# Processed 86200/1277367 instances
# Processed 86300/1277367 instances
# Processed 86400/1277367 instances
# Processed 86500/1277367 instances
# Processed 86600/1277367 instances
# Processed 86700/1277367 instances
# Processed 86800/1277367 instances
# Processed 86900/1277367 instances
# Processed 87000/1277367 instances
# Processed 87100/1277367 instances
# Processed 87200/1277367 instances
# Processed 87300/1277367 instances
# Processed 87400/1277367 instances
# Processed 87500/1277367 instances
# Processed 87600/1277367 instances
# Processed 87700/1277367 instances
# Processed 87800/1277367 instances
# Processed 87900/1277367 instances
# Processed 88000/1277367 instances
# Processed 88100/1277367 instances
# Processed 88200/1277367 instances
# Processed 88300/1277367 instances
# Processed 88400/1277367 instances
# Processed 88500/1277367 instances
# Processed 88600/1277367 instances
# Processed 88700/1277367 instances
# Processed 88800/1277367 instances
# Processed 88900/1277367 instances
# Processed 89000/1277367 instances
# Processed 89100/1277367 instances
# Processed 89200/1277367 instances
# Processed 89300/1277367 instances
# Processed 89400/1277367 instances
# Processed 89500/1277367 instances
# Processed 89600/1277367 instances
# Processed 89700/1277367 instances
# Processed 89800/1277367 instances
# Processed 89900/1277367 instances
# Processed 90000/1277367 instances
# Processed 90100/1277367 instances
# Processed 90200/1277367 instances
# Processed 90300/1277367 instances
# Processed 90400/1277367 instances
# Processed 90500/1277367 instances
# Processed 90600/1277367 instances
# Processed 90700/1277367 instances
# Processed 90800/1277367 instances
# Processed 90900/1277367 instances
# Processed 91000/1277367 instances
# Processed 91100/1277367 instances
# Processed 91200/1277367 instances
# Processed 91300/1277367 instances
# Processed 91400/1277367 instances
# Processed 91500/1277367 instances
# Processed 91600/1277367 instances
# Processed 91700/1277367 instances
# Processed 91800/1277367 instances
# Processed 91900/1277367 instances
# Processed 92000/1277367 instances
# Processed 92100/1277367 instances
# Processed 92200/1277367 instances
# Processed 92300/1277367 instances
# Processed 92400/1277367 instances
# Processed 92500/1277367 instances
# Processed 92600/1277367 instances
# Processed 92700/1277367 instances
# Processed 92800/1277367 instances
# Processed 92900/1277367 instances
# Processed 93000/1277367 instances
# Processed 93100/1277367 instances
# Processed 93200/1277367 instances
# Processed 93300/1277367 instances
# Processed 93400/1277367 instances
# Processed 93500/1277367 instances
# Processed 93600/1277367 instances
# Processed 93700/1277367 instances
# Processed 93800/1277367 instances
# Processed 93900/1277367 instances
# Processed 94000/1277367 instances
# Processed 94100/1277367 instances
# Processed 94200/1277367 instances
# Processed 94300/1277367 instances
# Processed 94400/1277367 instances
# Processed 94500/1277367 instances
# Processed 94600/1277367 instances
# Processed 94700/1277367 instances
# Processed 94800/1277367 instances
# Processed 94900/1277367 instances
# Processed 95000/1277367 instances
# Processed 95100/1277367 instances
# Processed 95200/1277367 instances
# Processed 95300/1277367 instances
# Processed 95400/1277367 instances
# Processed 95500/1277367 instances
# Processed 95600/1277367 instances
# Processed 95700/1277367 instances
# Processed 95800/1277367 instances
# Processed 95900/1277367 instances
# Processed 96000/1277367 instances
# Processed 96100/1277367 instances
# Processed 96200/1277367 instances
# Processed 96300/1277367 instances
# Processed 96400/1277367 instances
# Processed 96500/1277367 instances
# Processed 96600/1277367 instances
# Processed 96700/1277367 instances
# Processed 96800/1277367 instances
# Processed 96900/1277367 instances
# Processed 97000/1277367 instances
# Processed 97100/1277367 instances
# Processed 97200/1277367 instances
# Processed 97300/1277367 instances
# Processed 97400/1277367 instances
# Processed 97500/1277367 instances
# Processed 97600/1277367 instances
# Processed 97700/1277367 instances
# Processed 97800/1277367 instances
# Processed 97900/1277367 instances
# Processed 98000/1277367 instances
# Processed 98100/1277367 instances
# Processed 98200/1277367 instances
# Processed 98300/1277367 instances
# Processed 98400/1277367 instances
# Processed 98500/1277367 instances
# Processed 98600/1277367 instances
# Processed 98700/1277367 instances
# Processed 98800/1277367 instances
# Processed 98900/1277367 instances
# Processed 99000/1277367 instances
# Processed 99100/1277367 instances
# Processed 99200/1277367 instances
# Processed 99300/1277367 instances
# Processed 99400/1277367 instances
# Processed 99500/1277367 instances
# Processed 99600/1277367 instances
# Processed 99700/1277367 instances
# Processed 99800/1277367 instances
# Processed 99900/1277367 instances
# Processed 100000/1277367 instances
# Processed 100100/1277367 instances
# Processed 100200/1277367 instances
# Processed 100300/1277367 instances
# Processed 100400/1277367 instances
# Processed 100500/1277367 instances
# Processed 100600/1277367 instances
# Processed 100700/1277367 instances
# Processed 100800/1277367 instances
# Processed 100900/1277367 instances
# Processed 101000/1277367 instances
# Processed 101100/1277367 instances
# Processed 101200/1277367 instances
# Processed 101300/1277367 instances
# Processed 101400/1277367 instances
# Processed 101500/1277367 instances
# Processed 101600/1277367 instances
# Processed 101700/1277367 instances
# Processed 101800/1277367 instances
# Processed 101900/1277367 instances
# Processed 102000/1277367 instances
# Processed 102100/1277367 instances
# Processed 102200/1277367 instances
# Processed 102300/1277367 instances
# Processed 102400/1277367 instances
# Processed 102500/1277367 instances
# Processed 102600/1277367 instances
# Processed 102700/1277367 instances
# Processed 102800/1277367 instances
# Processed 102900/1277367 instances
# Processed 103000/1277367 instances
# Processed 103100/1277367 instances
# Processed 103200/1277367 instances
# Processed 103300/1277367 instances
# Processed 103400/1277367 instances
# Processed 103500/1277367 instances
# Processed 103600/1277367 instances
# Processed 103700/1277367 instances
# Processed 103800/1277367 instances
# Processed 103900/1277367 instances
# Processed 104000/1277367 instances
# Processed 104100/1277367 instances
# Processed 104200/1277367 instances
# Processed 104300/1277367 instances
# Processed 104400/1277367 instances
# Processed 104500/1277367 instances
# Processed 104600/1277367 instances
# Processed 104700/1277367 instances
# Processed 104800/1277367 instances
# Processed 104900/1277367 instances
# Processed 105000/1277367 instances
# Processed 105100/1277367 instances
# Processed 105200/1277367 instances
# Processed 105300/1277367 instances
# Processed 105400/1277367 instances
# Processed 105500/1277367 instances
# Processed 105600/1277367 instances
# Processed 105700/1277367 instances
# Processed 105800/1277367 instances
# Processed 105900/1277367 instances
# Processed 106000/1277367 instances
# Processed 106100/1277367 instances
# Processed 106200/1277367 instances
# Processed 106300/1277367 instances
# Processed 106400/1277367 instances
# Processed 106500/1277367 instances
# Processed 106600/1277367 instances
# Processed 106700/1277367 instances
# Processed 106800/1277367 instances
# Processed 106900/1277367 instances
# Processed 107000/1277367 instances
# Processed 107100/1277367 instances
# Processed 107200/1277367 instances
# Processed 107300/1277367 instances
# Processed 107400/1277367 instances
# Processed 107500/1277367 instances
# Processed 107600/1277367 instances
# Processed 107700/1277367 instances
# Processed 107800/1277367 instances
# Processed 107900/1277367 instances
# Processed 108000/1277367 instances
# Processed 108100/1277367 instances
# Processed 108200/1277367 instances
# Processed 108300/1277367 instances
# Processed 108400/1277367 instances
# Processed 108500/1277367 instances
# Processed 108600/1277367 instances
# Processed 108700/1277367 instances
# Processed 108800/1277367 instances
# Processed 108900/1277367 instances
# Processed 109000/1277367 instances
# Processed 109100/1277367 instances
# Processed 109200/1277367 instances
# Processed 109300/1277367 instances
# Processed 109400/1277367 instances
# Processed 109500/1277367 instances
# Processed 109600/1277367 instances
# Processed 109700/1277367 instances
# Processed 109800/1277367 instances
# Processed 109900/1277367 instances
# Processed 110000/1277367 instances
# Processed 110100/1277367 instances
# Processed 110200/1277367 instances
# Processed 110300/1277367 instances
# Processed 110400/1277367 instances
# Processed 110500/1277367 instances
# Processed 110600/1277367 instances
# Processed 110700/1277367 instances
# Processed 110800/1277367 instances
# Processed 110900/1277367 instances
# Processed 111000/1277367 instances
# Processed 111100/1277367 instances
# Processed 111200/1277367 instances
# Processed 111300/1277367 instances
# Processed 111400/1277367 instances
# Processed 111500/1277367 instances
# Processed 111600/1277367 instances
# Processed 111700/1277367 instances
# Processed 111800/1277367 instances
# Processed 111900/1277367 instances
# Processed 112000/1277367 instances
# Processed 112100/1277367 instances
# Processed 112200/1277367 instances
# Processed 112300/1277367 instances
# Processed 112400/1277367 instances
# Processed 112500/1277367 instances
# Processed 112600/1277367 instances
# Processed 112700/1277367 instances
# Processed 112800/1277367 instances
# Processed 112900/1277367 instances
# Processed 113000/1277367 instances
# Processed 113100/1277367 instances
# Processed 113200/1277367 instances
# Processed 113300/1277367 instances
# Processed 113400/1277367 instances
# Processed 113500/1277367 instances
# Processed 113600/1277367 instances
# Processed 113700/1277367 instances
# Processed 113800/1277367 instances
# Processed 113900/1277367 instances
# Processed 114000/1277367 instances
# Processed 114100/1277367 instances
# Processed 114200/1277367 instances
# Processed 114300/1277367 instances
# Processed 114400/1277367 instances
# Processed 114500/1277367 instances
# Processed 114600/1277367 instances
# Processed 114700/1277367 instances
# Processed 114800/1277367 instances
# Processed 114900/1277367 instances
# Processed 115000/1277367 instances
# Processed 115100/1277367 instances
# Processed 115200/1277367 instances
# Processed 115300/1277367 instances
# Processed 115400/1277367 instances
# Processed 115500/1277367 instances
# Processed 115600/1277367 instances
# Processed 115700/1277367 instances
# Processed 115800/1277367 instances
# Processed 115900/1277367 instances
# Processed 116000/1277367 instances
# Processed 116100/1277367 instances
# Processed 116200/1277367 instances
# Processed 116300/1277367 instances
# Processed 116400/1277367 instances
# Processed 116500/1277367 instances
# Processed 116600/1277367 instances
# Processed 116700/1277367 instances
# Processed 116800/1277367 instances
# Processed 116900/1277367 instances
# Processed 117000/1277367 instances
# Processed 117100/1277367 instances
# Processed 117200/1277367 instances
# Processed 117300/1277367 instances
# Processed 117400/1277367 instances
# Processed 117500/1277367 instances
# Processed 117600/1277367 instances
# Processed 117700/1277367 instances
# Processed 117800/1277367 instances
# Processed 117900/1277367 instances
# Processed 118000/1277367 instances
# Processed 118100/1277367 instances
# Processed 118200/1277367 instances
# Processed 118300/1277367 instances
# Processed 118400/1277367 instances
# Processed 118500/1277367 instances
# Processed 118600/1277367 instances
# Processed 118700/1277367 instances
# Processed 118800/1277367 instances
# Processed 118900/1277367 instances
# Processed 119000/1277367 instances
# Processed 119100/1277367 instances
# Processed 119200/1277367 instances
# Processed 119300/1277367 instances
# Processed 119400/1277367 instances
# Processed 119500/1277367 instances
# Processed 119600/1277367 instances
# Processed 119700/1277367 instances
# Processed 119800/1277367 instances
# Processed 119900/1277367 instances
# Processed 120000/1277367 instances
# Processed 120100/1277367 instances
# Processed 120200/1277367 instances
# Processed 120300/1277367 instances
# Processed 120400/1277367 instances
# Processed 120500/1277367 instances
# Processed 120600/1277367 instances
# Processed 120700/1277367 instances
# Processed 120800/1277367 instances
# Processed 120900/1277367 instances
# Processed 121000/1277367 instances
# Processed 121100/1277367 instances
# Processed 121200/1277367 instances
# Processed 121300/1277367 instances
# Processed 121400/1277367 instances
# Processed 121500/1277367 instances
# Processed 121600/1277367 instances
# Processed 121700/1277367 instances
# Processed 121800/1277367 instances
# Processed 121900/1277367 instances
# Processed 122000/1277367 instances
# Processed 122100/1277367 instances
# Processed 122200/1277367 instances
# Processed 122300/1277367 instances
# Processed 122400/1277367 instances
# Processed 122500/1277367 instances
# Processed 122600/1277367 instances
# Processed 122700/1277367 instances
# Processed 122800/1277367 instances
# Processed 122900/1277367 instances
# Processed 123000/1277367 instances
# Processed 123100/1277367 instances
# Processed 123200/1277367 instances
# Processed 123300/1277367 instances
# Processed 123400/1277367 instances
# Processed 123500/1277367 instances
# Processed 123600/1277367 instances
# Processed 123700/1277367 instances
# Processed 123800/1277367 instances
# Processed 123900/1277367 instances
# Processed 124000/1277367 instances
# Processed 124100/1277367 instances
# Processed 124200/1277367 instances
# Processed 124300/1277367 instances
# Processed 124400/1277367 instances
# Processed 124500/1277367 instances
# Processed 124600/1277367 instances
# Processed 124700/1277367 instances
# Processed 124800/1277367 instances
# Processed 124900/1277367 instances
# Processed 125000/1277367 instances
# Processed 125100/1277367 instances
# Processed 125200/1277367 instances
# Processed 125300/1277367 instances
# Processed 125400/1277367 instances
# Processed 125500/1277367 instances
# Processed 125600/1277367 instances
# Processed 125700/1277367 instances
# Processed 125800/1277367 instances
# Processed 125900/1277367 instances
# Processed 126000/1277367 instances
# Processed 126100/1277367 instances
# Processed 126200/1277367 instances
# Processed 126300/1277367 instances
# Processed 126400/1277367 instances
# Processed 126500/1277367 instances
# Processed 126600/1277367 instances
# Processed 126700/1277367 instances
# Processed 126800/1277367 instances
# Processed 126900/1277367 instances
# Processed 127000/1277367 instances
# Processed 127100/1277367 instances
# Processed 127200/1277367 instances
# Processed 127300/1277367 instances
# Processed 127400/1277367 instances
# Processed 127500/1277367 instances
# Processed 127600/1277367 instances
# Processed 127700/1277367 instances
# Processed 127800/1277367 instances
# Processed 127900/1277367 instances
# Processed 128000/1277367 instances
# Processed 128100/1277367 instances
# Processed 128200/1277367 instances
# Processed 128300/1277367 instances
# Processed 128400/1277367 instances
# Processed 128500/1277367 instances
# Processed 128600/1277367 instances
# Processed 128700/1277367 instances
# Processed 128800/1277367 instances
# Processed 128900/1277367 instances
# Processed 129000/1277367 instances
# Processed 129100/1277367 instances
# Processed 129200/1277367 instances
# Processed 129300/1277367 instances
# Processed 129400/1277367 instances
# Processed 129500/1277367 instances
# Processed 129600/1277367 instances
# Processed 129700/1277367 instances
# Processed 129800/1277367 instances
# Processed 129900/1277367 instances
# Processed 130000/1277367 instances
# Processed 130100/1277367 instances
# Processed 130200/1277367 instances
# Processed 130300/1277367 instances
# Processed 130400/1277367 instances
# Processed 130500/1277367 instances
# Processed 130600/1277367 instances
# Processed 130700/1277367 instances
# Processed 130800/1277367 instances
# Processed 130900/1277367 instances
# Processed 131000/1277367 instances
# Processed 131100/1277367 instances
# Processed 131200/1277367 instances
# Processed 131300/1277367 instances
# Processed 131400/1277367 instances
# Processed 131500/1277367 instances
# Processed 131600/1277367 instances
# Processed 131700/1277367 instances
# Processed 131800/1277367 instances
# Processed 131900/1277367 instances
# Processed 132000/1277367 instances
# Processed 132100/1277367 instances
# Processed 132200/1277367 instances
# Processed 132300/1277367 instances
# Processed 132400/1277367 instances
# Processed 132500/1277367 instances
# Processed 132600/1277367 instances
# Processed 132700/1277367 instances
# Processed 132800/1277367 instances
# Processed 132900/1277367 instances
# Processed 133000/1277367 instances
# Processed 133100/1277367 instances
# Processed 133200/1277367 instances
# Processed 133300/1277367 instances
# Processed 133400/1277367 instances
# Processed 133500/1277367 instances
# Processed 133600/1277367 instances
# Processed 133700/1277367 instances
# Processed 133800/1277367 instances
# Processed 133900/1277367 instances
# Processed 134000/1277367 instances
# Processed 134100/1277367 instances
# Processed 134200/1277367 instances
# Processed 134300/1277367 instances
# Processed 134400/1277367 instances
# Processed 134500/1277367 instances
# Processed 134600/1277367 instances
# Processed 134700/1277367 instances
# Processed 134800/1277367 instances
# Processed 134900/1277367 instances
# Processed 135000/1277367 instances
# Processed 135100/1277367 instances
# Processed 135200/1277367 instances
# Processed 135300/1277367 instances
# Processed 135400/1277367 instances
# Processed 135500/1277367 instances
# Processed 135600/1277367 instances
# Processed 135700/1277367 instances
# Processed 135800/1277367 instances
# Processed 135900/1277367 instances
# Processed 136000/1277367 instances
# Processed 136100/1277367 instances
# Processed 136200/1277367 instances
# Processed 136300/1277367 instances
# Processed 136400/1277367 instances
# Processed 136500/1277367 instances
# Processed 136600/1277367 instances
# Processed 136700/1277367 instances
# Processed 136800/1277367 instances
# Processed 136900/1277367 instances
# Processed 137000/1277367 instances
# Processed 137100/1277367 instances
# Processed 137200/1277367 instances
# Processed 137300/1277367 instances
# Processed 137400/1277367 instances
# Processed 137500/1277367 instances
# Processed 137600/1277367 instances
# Processed 137700/1277367 instances
# Processed 137800/1277367 instances
# Processed 137900/1277367 instances
# Processed 138000/1277367 instances
# Processed 138100/1277367 instances
# Processed 138200/1277367 instances
# Processed 138300/1277367 instances
# Processed 138400/1277367 instances
# Processed 138500/1277367 instances
# Processed 138600/1277367 instances
# Processed 138700/1277367 instances
# Processed 138800/1277367 instances
# Processed 138900/1277367 instances
# Processed 139000/1277367 instances
# Processed 139100/1277367 instances
# Processed 139200/1277367 instances
# Processed 139300/1277367 instances
# Processed 139400/1277367 instances
# Processed 139500/1277367 instances
# Processed 139600/1277367 instances
# ...
# Processed 1233000/1277367 instances
# Processed 1233100/1277367 instances
# Processed 1233200/1277367 instances
# Processed 1233300/1277367 instances
# Processed 1233400/1277367 instances
# Processed 1233500/1277367 instances
# Processed 1233600/1277367 instances
# Processed 1233700/1277367 instances
# Processed 1233800/1277367 instances
# Processed 1233900/1277367 instances
# Processed 1234000/1277367 instances
# Processed 1234100/1277367 instances
# Processed 1234200/1277367 instances
# Processed 1234300/1277367 instances
# Processed 1234400/1277367 instances
# Processed 1234500/1277367 instances
# Processed 1234600/1277367 instances
# Processed 1234700/1277367 instances
# Processed 1234800/1277367 instances
# Processed 1234900/1277367 instances
# Processed 1235000/1277367 instances
# Processed 1235100/1277367 instances
# Processed 1235200/1277367 instances
# Processed 1235300/1277367 instances
# Processed 1235400/1277367 instances
# Processed 1235500/1277367 instances
# Processed 1235600/1277367 instances
# Processed 1235700/1277367 instances
# Processed 1235800/1277367 instances
# Processed 1235900/1277367 instances
# Processed 1236000/1277367 instances
# Processed 1236100/1277367 instances
# Processed 1236200/1277367 instances
# Processed 1236300/1277367 instances
# Processed 1236400/1277367 instances
# Processed 1236500/1277367 instances
# Processed 1236600/1277367 instances
# Processed 1236700/1277367 instances
# Processed 1236800/1277367 instances
# Processed 1236900/1277367 instances
# Processed 1237000/1277367 instances
# Processed 1237100/1277367 instances
# Processed 1237200/1277367 instances
# Processed 1237300/1277367 instances
# Processed 1237400/1277367 instances
# Processed 1237500/1277367 instances
# Processed 1237600/1277367 instances
# Processed 1237700/1277367 instances
# Processed 1237800/1277367 instances
# Processed 1237900/1277367 instances
# Processed 1238000/1277367 instances
# Processed 1238100/1277367 instances
# Processed 1238200/1277367 instances
# Processed 1238300/1277367 instances
# Processed 1238400/1277367 instances
# Processed 1238500/1277367 instances
# Processed 1238600/1277367 instances
# Processed 1238700/1277367 instances
# Processed 1238800/1277367 instances
# Processed 1238900/1277367 instances
# Processed 1239000/1277367 instances
# Processed 1239100/1277367 instances
# Processed 1239200/1277367 instances
# Processed 1239300/1277367 instances
# Processed 1239400/1277367 instances
# Processed 1239500/1277367 instances
# Processed 1239600/1277367 instances
# Processed 1239700/1277367 instances
# Processed 1239800/1277367 instances
# Processed 1239900/1277367 instances
# Processed 1240000/1277367 instances
# Processed 1240100/1277367 instances
# Processed 1240200/1277367 instances
# Processed 1240300/1277367 instances
# Processed 1240400/1277367 instances
# Processed 1240500/1277367 instances
# Processed 1240600/1277367 instances
# Processed 1240700/1277367 instances
# Processed 1240800/1277367 instances
# Processed 1240900/1277367 instances
# Processed 1241000/1277367 instances
# Processed 1241100/1277367 instances
# Processed 1241200/1277367 instances
# Processed 1241300/1277367 instances
# Processed 1241400/1277367 instances
# Processed 1241500/1277367 instances
# Processed 1241600/1277367 instances
# Processed 1241700/1277367 instances
# Processed 1241800/1277367 instances
# Processed 1241900/1277367 instances
# Processed 1242000/1277367 instances
# Processed 1242100/1277367 instances
# Processed 1242200/1277367 instances
# Processed 1242300/1277367 instances
# Processed 1242400/1277367 instances
# Processed 1242500/1277367 instances
# Processed 1242600/1277367 instances
# Processed 1242700/1277367 instances
# Processed 1242800/1277367 instances
# Processed 1242900/1277367 instances
# Processed 1243000/1277367 instances
# Processed 1243100/1277367 instances
# Processed 1243200/1277367 instances
# Processed 1243300/1277367 instances
# Processed 1243400/1277367 instances
# Processed 1243500/1277367 instances
# Processed 1243600/1277367 instances
# Processed 1243700/1277367 instances
# Processed 1243800/1277367 instances
# Processed 1243900/1277367 instances
# Processed 1244000/1277367 instances
# Processed 1244100/1277367 instances
# Processed 1244200/1277367 instances
# Processed 1244300/1277367 instances
# Processed 1244400/1277367 instances
# Processed 1244500/1277367 instances
# Processed 1244600/1277367 instances
# Processed 1244700/1277367 instances
# Processed 1244800/1277367 instances
# Processed 1244900/1277367 instances
# Processed 1245000/1277367 instances
# Processed 1245100/1277367 instances
# Processed 1245200/1277367 instances
# Processed 1245300/1277367 instances
# Processed 1245400/1277367 instances
# Processed 1245500/1277367 instances
# Processed 1245600/1277367 instances
# Processed 1245700/1277367 instances
# Processed 1245800/1277367 instances
# Processed 1245900/1277367 instances
# Processed 1246000/1277367 instances
# Processed 1246100/1277367 instances
# Processed 1246200/1277367 instances
# Processed 1246300/1277367 instances
# Processed 1246400/1277367 instances
# Processed 1246500/1277367 instances
# Processed 1246600/1277367 instances
# Processed 1246700/1277367 instances
# Processed 1246800/1277367 instances
# Processed 1246900/1277367 instances
# Processed 1247000/1277367 instances
# Processed 1247100/1277367 instances
# Processed 1247200/1277367 instances
# Processed 1247300/1277367 instances
# Processed 1247400/1277367 instances
# Processed 1247500/1277367 instances
# Processed 1247600/1277367 instances
# Processed 1247700/1277367 instances
# Processed 1247800/1277367 instances
# Processed 1247900/1277367 instances
# Processed 1248000/1277367 instances
# Processed 1248100/1277367 instances
# Processed 1248200/1277367 instances
# Processed 1248300/1277367 instances
# Processed 1248400/1277367 instances
# Processed 1248500/1277367 instances
# Processed 1248600/1277367 instances
# Processed 1248700/1277367 instances
# Processed 1248800/1277367 instances
# Processed 1248900/1277367 instances
# Processed 1249000/1277367 instances
# Processed 1249100/1277367 instances
# Processed 1249200/1277367 instances
# Processed 1249300/1277367 instances
# Processed 1249400/1277367 instances
# Processed 1249500/1277367 instances
# Processed 1249600/1277367 instances
# Processed 1249700/1277367 instances
# Processed 1249800/1277367 instances
# Processed 1249900/1277367 instances
# Processed 1250000/1277367 instances
# Processed 1250100/1277367 instances
# Processed 1250200/1277367 instances
# Processed 1250300/1277367 instances
# Processed 1250400/1277367 instances
# Processed 1250500/1277367 instances
# Processed 1250600/1277367 instances
# Processed 1250700/1277367 instances
# Processed 1250800/1277367 instances
# Processed 1250900/1277367 instances
# Processed 1251000/1277367 instances
# Processed 1251100/1277367 instances
# Processed 1251200/1277367 instances
# Processed 1251300/1277367 instances
# Processed 1251400/1277367 instances
# Processed 1251500/1277367 instances
# Processed 1251600/1277367 instances
# Processed 1251700/1277367 instances
# Processed 1251800/1277367 instances
# Processed 1251900/1277367 instances
# Processed 1252000/1277367 instances
# Processed 1252100/1277367 instances
# Processed 1252200/1277367 instances
# Processed 1252300/1277367 instances
# Processed 1252400/1277367 instances
# Processed 1252500/1277367 instances
# Processed 1252600/1277367 instances
# Processed 1252700/1277367 instances
# Processed 1252800/1277367 instances
# Processed 1252900/1277367 instances
# Processed 1253000/1277367 instances
# Processed 1253100/1277367 instances
# Processed 1253200/1277367 instances
# Processed 1253300/1277367 instances
# Processed 1253400/1277367 instances
# Processed 1253500/1277367 instances
# Processed 1253600/1277367 instances
# Processed 1253700/1277367 instances
# Processed 1253800/1277367 instances
# Processed 1253900/1277367 instances
# Processed 1254000/1277367 instances
# Processed 1254100/1277367 instances
# Processed 1254200/1277367 instances
# Processed 1254300/1277367 instances
# Processed 1254400/1277367 instances
# Processed 1254500/1277367 instances
# Processed 1254600/1277367 instances
# Processed 1254700/1277367 instances
# Processed 1254800/1277367 instances
# Processed 1254900/1277367 instances
# Processed 1255000/1277367 instances
# Processed 1255100/1277367 instances
# Processed 1255200/1277367 instances
# Processed 1255300/1277367 instances
# Processed 1255400/1277367 instances
# Processed 1255500/1277367 instances
# Processed 1255600/1277367 instances
# Processed 1255700/1277367 instances
# Processed 1255800/1277367 instances
# Processed 1255900/1277367 instances
# Processed 1256000/1277367 instances
# Processed 1256100/1277367 instances
# Processed 1256200/1277367 instances
# Processed 1256300/1277367 instances
# Processed 1256400/1277367 instances
# Processed 1256500/1277367 instances
# Processed 1256600/1277367 instances
# Processed 1256700/1277367 instances
# Processed 1256800/1277367 instances
# Processed 1256900/1277367 instances
# Processed 1257000/1277367 instances
# Processed 1257100/1277367 instances
# Processed 1257200/1277367 instances
# Processed 1257300/1277367 instances
# Processed 1257400/1277367 instances
# Processed 1257500/1277367 instances
# Processed 1257600/1277367 instances
# Processed 1257700/1277367 instances
# Processed 1257800/1277367 instances
# Processed 1257900/1277367 instances
# Processed 1258000/1277367 instances
# Processed 1258100/1277367 instances
# Processed 1258200/1277367 instances
# Processed 1258300/1277367 instances
# Processed 1258400/1277367 instances
# Processed 1258500/1277367 instances
# Processed 1258600/1277367 instances
# Processed 1258700/1277367 instances
# Processed 1258800/1277367 instances
# Processed 1258900/1277367 instances
# Processed 1259000/1277367 instances
# Processed 1259100/1277367 instances
# Processed 1259200/1277367 instances
# Processed 1259300/1277367 instances
# Processed 1259400/1277367 instances
# Processed 1259500/1277367 instances
# Processed 1259600/1277367 instances
# Processed 1259700/1277367 instances
# Processed 1259800/1277367 instances
# Processed 1259900/1277367 instances
# Processed 1260000/1277367 instances
# Processed 1260100/1277367 instances
# Processed 1260200/1277367 instances
# Processed 1260300/1277367 instances
# Processed 1260400/1277367 instances
# Processed 1260500/1277367 instances
# Processed 1260600/1277367 instances
# Processed 1260700/1277367 instances
# Processed 1260800/1277367 instances
# Processed 1260900/1277367 instances
# Processed 1261000/1277367 instances
# Processed 1261100/1277367 instances
# Processed 1261200/1277367 instances
# Processed 1261300/1277367 instances
# Processed 1261400/1277367 instances
# Processed 1261500/1277367 instances
# Processed 1261600/1277367 instances
# Processed 1261700/1277367 instances
# Processed 1261800/1277367 instances
# Processed 1261900/1277367 instances
# Processed 1262000/1277367 instances
# Processed 1262100/1277367 instances
# Processed 1262200/1277367 instances
# Processed 1262300/1277367 instances
# Processed 1262400/1277367 instances
# Processed 1262500/1277367 instances
# Processed 1262600/1277367 instances
# Processed 1262700/1277367 instances
# Processed 1262800/1277367 instances
# Processed 1262900/1277367 instances
# Processed 1263000/1277367 instances
# Processed 1263100/1277367 instances
# Processed 1263200/1277367 instances
# Processed 1263300/1277367 instances
# Processed 1263400/1277367 instances
# Processed 1263500/1277367 instances
# Processed 1263600/1277367 instances
# Processed 1263700/1277367 instances
# Processed 1263800/1277367 instances
# Processed 1263900/1277367 instances
# Processed 1264000/1277367 instances
# Processed 1264100/1277367 instances
# Processed 1264200/1277367 instances
# Processed 1264300/1277367 instances
# Processed 1264400/1277367 instances
# Processed 1264500/1277367 instances
# Processed 1264600/1277367 instances
# Processed 1264700/1277367 instances
# Processed 1264800/1277367 instances
# Processed 1264900/1277367 instances
# Processed 1265000/1277367 instances
# Processed 1265100/1277367 instances
# Processed 1265200/1277367 instances
# Processed 1265300/1277367 instances
# Processed 1265400/1277367 instances
# Processed 1265500/1277367 instances
# Processed 1265600/1277367 instances
# Processed 1265700/1277367 instances
# Processed 1265800/1277367 instances
# Processed 1265900/1277367 instances
# Processed 1266000/1277367 instances
# Processed 1266100/1277367 instances
# Processed 1266200/1277367 instances
# Processed 1266300/1277367 instances
# Processed 1266400/1277367 instances
# Processed 1266500/1277367 instances
# Processed 1266600/1277367 instances
# Processed 1266700/1277367 instances
# Processed 1266800/1277367 instances
# Processed 1266900/1277367 instances
# Processed 1267000/1277367 instances
# Processed 1267100/1277367 instances
# Processed 1267200/1277367 instances
# Processed 1267300/1277367 instances
# Processed 1267400/1277367 instances
# Processed 1267500/1277367 instances
# Processed 1267600/1277367 instances
# Processed 1267700/1277367 instances
# Processed 1267800/1277367 instances
# Processed 1267900/1277367 instances
# Processed 1268000/1277367 instances
# Processed 1268100/1277367 instances
# Processed 1268200/1277367 instances
# Processed 1268300/1277367 instances
# Processed 1268400/1277367 instances
# Processed 1268500/1277367 instances
# Processed 1268600/1277367 instances
# Processed 1268700/1277367 instances
# Processed 1268800/1277367 instances
# Processed 1268900/1277367 instances
# Processed 1269000/1277367 instances
# Processed 1269100/1277367 instances
# Processed 1269200/1277367 instances
# Processed 1269300/1277367 instances
# Processed 1269400/1277367 instances
# Processed 1269500/1277367 instances
# Processed 1269600/1277367 instances
# Processed 1269700/1277367 instances
# Processed 1269800/1277367 instances
# Processed 1269900/1277367 instances
# Processed 1270000/1277367 instances
# Processed 1270100/1277367 instances
# Processed 1270200/1277367 instances
# Processed 1270300/1277367 instances
# Processed 1270400/1277367 instances
# Processed 1270500/1277367 instances
# Processed 1270600/1277367 instances
# Processed 1270700/1277367 instances
# Processed 1270800/1277367 instances
# Processed 1270900/1277367 instances
# Processed 1271000/1277367 instances
# Processed 1271100/1277367 instances
# Processed 1271200/1277367 instances
# Processed 1271300/1277367 instances
# Processed 1271400/1277367 instances
# Processed 1271500/1277367 instances
# Processed 1271600/1277367 instances
# Processed 1271700/1277367 instances
# Processed 1271800/1277367 instances
# Processed 1271900/1277367 instances
# Processed 1272000/1277367 instances
# Processed 1272100/1277367 instances
# Processed 1272200/1277367 instances
# Processed 1272300/1277367 instances
# Processed 1272400/1277367 instances
# Processed 1272500/1277367 instances
# Processed 1272600/1277367 instances
# Processed 1272700/1277367 instances
# Processed 1272800/1277367 instances
# Processed 1272900/1277367 instances
# Processed 1273000/1277367 instances
# Processed 1273100/1277367 instances
# Processed 1273200/1277367 instances
# Processed 1273300/1277367 instances
# Processed 1273400/1277367 instances
# Processed 1273500/1277367 instances
# Processed 1273600/1277367 instances
# Processed 1273700/1277367 instances
# Processed 1273800/1277367 instances
# Processed 1273900/1277367 instances
# Processed 1274000/1277367 instances
# Processed 1274100/1277367 instances
# Processed 1274200/1277367 instances
# Processed 1274300/1277367 instances
# Processed 1274400/1277367 instances
# Processed 1274500/1277367 instances
# Processed 1274600/1277367 instances
# Processed 1274700/1277367 instances
# Processed 1274800/1277367 instances
# Processed 1274900/1277367 instances
# Processed 1275000/1277367 instances
# Processed 1275100/1277367 instances
# Processed 1275200/1277367 instances
# Processed 1275300/1277367 instances
# Processed 1275400/1277367 instances
# Processed 1275500/1277367 instances
# Processed 1275600/1277367 instances
# Processed 1275700/1277367 instances
# Processed 1275800/1277367 instances
# Processed 1275900/1277367 instances
# Processed 1276000/1277367 instances
# Processed 1276100/1277367 instances
# Processed 1276200/1277367 instances
# Processed 1276300/1277367 instances
# Processed 1276400/1277367 instances
# Processed 1276500/1277367 instances
# Processed 1276600/1277367 instances
# Processed 1276700/1277367 instances
# Processed 1276800/1277367 instances
# Processed 1276900/1277367 instances
# Processed 1277000/1277367 instances
# Processed 1277100/1277367 instances
# Processed 1277200/1277367 instances
# Processed 1277300/1277367 instances

# %%
print(f"Total Execution Time: {end_time - start_time:.2f} seconds")
print(f"Total time spent on drift detection: {drift_time_total:.2f} seconds")
print(f"Total time spent updating metrics: {metrics_time_total:.2f} seconds")
print(f"Total drifts detected: {len(drift_events)}")
# Out:
# Total Execution Time: 4706.81 seconds
# Total time spent on drift detection: 3.98 seconds
# Total time spent updating metrics: 6.59 seconds
# Total drifts detected: 12

# %%
instances_processed = list(range(1, len(metric_logs['accuracy']) + 1))

# Create a plot
plt.figure(figsize=(6, 4))
plt.plot(instances_processed, metric_logs['accuracy'], label='Accuracy')
plt.plot(instances_processed, metric_logs['precision'], label='Precision', linestyle=':')
plt.plot(instances_processed, metric_logs['recall'], label='Recall', linestyle='--')
plt.plot(instances_processed, metric_logs['f1_score'], label='F1-Score', linestyle='-.')

# Add drift events without duplicating the label
for i, drift_event in enumerate(drift_events):
    plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if i == 0 else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed')
plt.ylabel('Metric Value')
#plt.title('Performance Metrics Over Time')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='best')

# Save or show the plot
plt.savefig('PM2-1.png', dpi=1000, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
instances_processed = list(range(1, len(metric_logs['accuracy']) + 1))

# Create a plot
plt.figure(figsize=(6, 4))
plt.plot(instances_processed, metric_logs['accuracy'], label='Accuracy')
plt.plot(instances_processed, metric_logs['precision'], label='Precision', linestyle=':')
plt.plot(instances_processed, metric_logs['recall'], label='Recall', linestyle='--')
plt.plot(instances_processed, metric_logs['f1_score'], label='F1-Score', linestyle='-.')

# Add drift events without duplicating the label
for i, drift_event in enumerate(drift_events):
    plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if i == 0 else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed')
plt.ylabel('Metric Value')
#plt.title('Performance Metrics Over Time')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='best')

plt.ylim([0.9, 1.001])

# Save or show the plot
plt.savefig('PM2-2.png', dpi=1000, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
instances_processed = list(range(1, len(metric_logs['accuracy']) + 1))

# Create a plot
plt.figure(figsize=(6, 4))
plt.plot(instances_processed, metric_logs['accuracy'], label='Accuracy')
plt.plot(instances_processed, metric_logs['precision'], label='Precision', linestyle=':')
plt.plot(instances_processed, metric_logs['recall'], label='Recall', linestyle='--')
plt.plot(instances_processed, metric_logs['f1_score'], label='F1-Score', linestyle='-.')

# Add drift events without duplicating the label
for i, drift_event in enumerate(drift_events):
    plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if i == 0 else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed')
plt.ylabel('Metric Value')
#plt.title('Performance Metrics Over Time')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='best')

plt.xlim([-0.01, 100])

# Save or show the plot
plt.savefig('PM2-3.png', dpi=1000, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
instances_processed = list(range(1, len(metric_logs['accuracy']) + 1))

# Create a plot
plt.figure(figsize=(6, 4))
plt.plot(instances_processed, metric_logs['accuracy'], label='Accuracy')
plt.plot(instances_processed, metric_logs['precision'], label='Precision', linestyle=':')
plt.plot(instances_processed, metric_logs['recall'], label='Recall', linestyle='--')
plt.plot(instances_processed, metric_logs['f1_score'], label='F1-Score', linestyle='-.')

# Add drift events without duplicating the label
for i, drift_event in enumerate(drift_events):
    plt.axvline(x=drift_event, color='blue', linestyle='--', linewidth=1, label='Drift Event' if i == 0 else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed')
plt.ylabel('Metric Value')
#plt.title('Performance Metrics Over Time')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='best')

plt.xlim([-0.01, 200000])
plt.ylim([0.98, 1.001])

# Save or show the plot
plt.savefig('PM2-4.png', dpi=1000, bbox_inches='tight')
plt.tight_layout()
plt.show()

# %%
# Compute descriptive statistics
mean_time = np.mean(processing_times)
median_time = np.median(processing_times)
std_dev_time = np.std(processing_times)
outlier_threshold = mean_time + 3 * std_dev_time  # Define outliers as 3 standard deviations above the mean
outlier_counts = sum(time > outlier_threshold for time in processing_times)

# Plot histogram
plt.figure(figsize=(14, 5))
counts, bins, bars = plt.hist(processing_times, bins=30, edgecolor='white', color='blue', alpha=0.7, label='Processing Times')

# Add vertical lines for statistics
plt.axvline(mean_time, color='red', linestyle='dashed', linewidth=1.5, label=f'Mean: {mean_time:.4f}s')
plt.axvline(median_time, color='orange', linestyle='dashed', linewidth=1.5, label=f'Median: {median_time:.4f}s')
plt.axvline(mean_time + std_dev_time, color='deeppink', linestyle='dotted', linewidth=1, label=f'+1 Std Dev: {mean_time + std_dev_time:.4f}s')
plt.axvline(mean_time - std_dev_time, color='deeppink', linestyle='dotted', linewidth=1, label=f'-1 Std Dev: {mean_time - std_dev_time:.4f}s')
plt.axvline(outlier_threshold, color='green', linestyle='dotted', linewidth=1.5, label=f'Outlier Threshold: {outlier_threshold:.4f}s')

# Add annotations to the histogram bars
for count, bin_edge in zip(counts, bins):
    if count > 0:  # Avoid clutter for empty bins
        plt.text(bin_edge + (bins[1] - bins[0]) / 2, count, f'{int(count)}', ha='center', va='bottom')

# Annotate outliers
plt.text(outlier_threshold, max(counts) * 0.8, f'{outlier_counts} outliers', color='green', ha='left')

# Add labels, legend, and title
plt.xlabel('Processing Time (seconds)')
plt.ylabel('Frequency')
#plt.title('Enhanced Distribution of Instance Processing Times')
# Add grid and legend
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5)
plt.legend()
plt.savefig('PT2.png', dpi=1000, bbox_inches='tight')

# Show the plot
plt.show()

# %%
# Calculate cumulative sums
cumulative_drift_time = np.cumsum(drift_time_per_instance)
cumulative_metrics_time = np.cumsum(metrics_time_per_instance)
cumulative_total_time = cumulative_drift_time + cumulative_metrics_time
processing_time = list(range(len(cumulative_drift_time)))

epsilon = 1e-10  # A small value to avoid division by zero

# Safely handle division by zero using NumPy
cumulative_total_time = np.where(cumulative_total_time == 0, epsilon, cumulative_total_time)

# Convert to percentages
cumulative_drift_percent = cumulative_drift_time / cumulative_total_time * 100
cumulative_metrics_percent = cumulative_metrics_time / cumulative_total_time * 100

# Create dual-axis plot
fig, ax1 = plt.subplots(figsize=(10, 5))

# Primary Y-Axis (percentages)
ax1.stackplot(processing_time, cumulative_drift_percent, cumulative_metrics_percent,
              labels=['Drift Detection (Percent)', 'Metrics Update (Percent)'],
              colors=['#FF9999', '#99CCFF'], alpha=0.8)
ax1.set_xlabel('Instances Processed')
ax1.set_ylabel('Cumulative Contribution (%)')
ax1.legend(loc='upper left')
ax1.grid(True, linestyle='--', linewidth=0.5)

# Secondary Y-Axis (total time)
ax2 = ax1.twinx()
ax2.plot(processing_time, cumulative_total_time, color='black', linestyle='--', linewidth=1, label='Total Cumulative Time')
ax2.set_ylabel('Total Cumulative Time (seconds)')
ax2.legend(loc='upper right')

# Annotate drift events
for i, drift_instance in enumerate(drift_events):
    ax1.axvline(drift_instance, color='blue', linestyle='dotted', linewidth=1)
    ax1.text(drift_instance, 2, f'Drift - {drift_instance}', rotation=90, color='blue')

# Add title and save
#plt.title('Enhanced Cumulative Time Analysis with Dual Y-Axis')
plt.tight_layout()
plt.savefig('CT2.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
if drift_events:
    # Extract pre-drift and post-drift accuracies for each drift event
    pre_drift_accuracy = [metric_logs['accuracy'][i-1] for i in drift_events]
    post_drift_accuracy = [metric_logs['accuracy'][i] for i in drift_events]
    drift_labels = [f'Drift {i+1}' for i in range(len(drift_events))]
    
    # Sort drift events by the magnitude of accuracy change
    sorted_indices = sorted(range(len(drift_events)), key=lambda i: abs(pre_drift_accuracy[i] - post_drift_accuracy[i]), reverse=True)
    pre_drift_accuracy = [pre_drift_accuracy[i] for i in sorted_indices]
    post_drift_accuracy = [post_drift_accuracy[i] for i in sorted_indices]
    drift_labels = [drift_labels[i] for i in sorted_indices]
    
    x = range(len(drift_events))  # X-axis positions for drift events

    # Set up the figure
    plt.figure(figsize=(15, 5))
    
    # Bar width for side-by-side comparison
    bar_width = 0.4
    
    # Plot pre-drift and post-drift accuracies
    plt.bar(x, pre_drift_accuracy, width=bar_width, label='Pre-Drift Accuracy', color='#1f77b4', alpha=0.8)
    plt.bar([i + bar_width for i in x], post_drift_accuracy, width=bar_width, label='Post-Drift Accuracy', color='#ff7f0e', alpha=0.8)
    
    # Annotate bars with their accuracy values
    for i, (pre, post) in enumerate(zip(pre_drift_accuracy, post_drift_accuracy)):
        plt.text(i, pre, f'{pre:.2f}', ha='center', va='bottom', color='black')
        plt.text(i + bar_width, post, f'{post:.2f}', ha='center', va='bottom', color='black')

        # Add percentage change annotation
        pct_change = ((post - pre) / pre) * 100 if pre > 0 else 0
        plt.text(i + bar_width / 2, max(pre, post) + 0.009, f'{pct_change:+.6f}%', ha='center', color='green' if pct_change > 0 else 'red')
    
    # Add descriptive x-axis labels for drift events
    plt.xticks([i + bar_width / 2 for i in x], drift_labels)

    # Calculate and plot the average accuracy as a horizontal line
    avg_accuracy = sum(metric_logs['accuracy']) / len(metric_logs['accuracy'])
    plt.axhline(avg_accuracy, color='red', linestyle='--', linewidth=1, label=f'Average Accuracy: {avg_accuracy:.2f}')

    # Add labels, title, grid, and legend
    plt.xlabel('Drift Event')
    plt.ylabel('Accuracy')
    #plt.title('Model Accuracy Before and After Drift (with Percentage Changes)')
    plt.ylim(0.9, 1.013)  # Adjust y-axis limits for better focus
    plt.grid(True, which='both', linestyle='--', linewidth=0.5)
    plt.legend(loc='lower right')
    plt.tight_layout()

    # Save the chart as a high-resolution image (optional)
    plt.savefig('MA2.png', dpi=1000, bbox_inches='tight')

    # Display the plot
    plt.show()
else:
    print("No drift events detected.")

# %%
# Initialize class distribution dictionary with cumulative sums
class_distribution = {cls: [0] for cls in set(y)}  # Start with 0 for all classes

# Update cumulative counts for each class
for i, cls in enumerate(y):
    for key in class_distribution:
        class_distribution[key].append(class_distribution[key][-1] + (1 if cls == key else 0))

# Remove the initial zero added to each class (optional for clarity)
for key in class_distribution:
    class_distribution[key] = class_distribution[key][1:]

plt.figure(figsize=(4, 4))
for cls, counts in class_distribution.items():
    plt.plot(instances_processed, counts, label=f'Class {cls}')
plt.xlabel('Instances Processed')
plt.ylabel('Class Distribution')
#plt.title('Class Distribution Over Time')
# Add grid and legend
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='best')
plt.savefig('CD2.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# Smooth function
def smooth(data, window_size=50):
    return np.convolve(data, np.ones(window_size) / window_size, mode='same')

# Initialize class distribution dictionary
class_distribution = {cls: [] for cls in set(y)}

# Initialize running counter for each class
running_counts = Counter()

# Generate instances_processed to match the length of y
instances_processed = list(range(1, len(y) + 1))

# Calculate cumulative counts efficiently
for i, label in enumerate(y):
    running_counts[label] += 1  # Update count for the current label
    for cls in class_distribution.keys():
        class_distribution[cls].append(running_counts[cls])

# Normalize cumulative counts to proportions
total_instances = np.arange(1, len(y) + 1)  # Matches the length of instances_processed
normalized_distribution = {cls: np.array(counts) / total_instances for cls, counts in class_distribution.items()}

# Smooth the data
smoothed_distribution = {cls: smooth(proportions, window_size=50) for cls, proportions in normalized_distribution.items()}

# Plot class distribution over time (full view)
plt.figure(figsize=(6, 4))
for cls, proportions in smoothed_distribution.items():
    plt.plot(instances_processed, proportions, label=f'Class {cls}', linewidth=1, linestyle='--', alpha=0.8)
    
# Add drift markers
for drift_event in drift_events:
    plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if drift_event == drift_events[0] else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed')
plt.ylabel('Class Proportion')
#plt.title('Smoothed Normalized Class Distribution Over Time with Drift Markers')
plt.grid(True, which='both', axis='y', linestyle='--', linewidth=0.5)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4)
plt.tight_layout()
plt.savefig('SD2.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# Zoomed-in view for the first 1000 instances
plt.figure(figsize=(6, 4))
for cls, proportions in smoothed_distribution.items():
    plt.plot(instances_processed[:1000], proportions[:1000], label=f'Class {cls}', linewidth=1, linestyle='--', alpha=0.8)

# Add drift markers (only for zoomed-in range)
for drift_event in drift_events:
    if drift_event <= 1000:
        plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if drift_event == drift_events[0] else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed (First 1000)')
plt.ylabel('Class Proportion')
#plt.title('Zoomed-In Class Distribution (First 1000 Instances) with Drift Markers')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4)
plt.tight_layout()
plt.savefig('ZD2-1.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# Zoomed-in view for the first 1000 instances
plt.figure(figsize=(6, 4))
for cls, proportions in smoothed_distribution.items():
    plt.plot(instances_processed[1276367:], proportions[1276367:], label=f'Class {cls}', linewidth=1, linestyle='--', alpha=0.8)

# Add drift markers (only for zoomed-in range)
for drift_event in drift_events:
    if drift_event >= 1276367:
        plt.axvline(x=drift_event, color='blue', linestyle=':', linewidth=1, label='Drift Event' if drift_event == drift_events[0] else "")

# Add labels, title, grid, and legend
plt.xlabel('Instances Processed (Last 1000)')
plt.ylabel('Class Proportion')
#plt.title('Zoomed-In Class Distribution (First 1000 Instances) with Drift Markers')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4)
plt.tight_layout()
plt.savefig('ZD2-2.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# Simulate feature importances as uniform values for demonstration purposes
feature_importances = np.random.uniform(0, 1, len(X.columns))  # Replace with your actual method if available
feature_names = X.columns  # Assuming X is your DataFrame with feature names

# Sort feature importances and corresponding feature names in descending order
sorted_indices = np.argsort(feature_importances)[::-1]
sorted_feature_importances = feature_importances[sorted_indices]
sorted_feature_names = feature_names[sorted_indices]

# Plot feature importances as a horizontal bar chart
plt.figure(figsize=(6, 8))
plt.barh(range(len(sorted_feature_importances)), sorted_feature_importances, color='green')
plt.yticks(range(len(sorted_feature_importances)), sorted_feature_names)
plt.xlabel('Importance')
#plt.title('Feature Importance (Sorted)')
plt.grid(True, which='both', axis='x', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig('FI2.png', dpi=1000, bbox_inches='tight')
plt.show()

# %%
# Print Final Metrics
print(f"Accuracy: {metric_accuracy.get():.4f}")
print(f"Precision: {metric_precision.get():.4f}")
print(f"Recall: {metric_recall.get():.4f}")
print(f"F1-Score: {metric_f1.get():.4f}")
# Out:
# Accuracy: 0.9913
# Precision: 0.9999
# Recall: 0.9914
# F1-Score: 0.9956
